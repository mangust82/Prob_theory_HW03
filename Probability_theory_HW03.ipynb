# %%
# Даны значения зарплат из выборки выпускников: 100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150.
# Посчитать (желательно без использования статистических методов наподобие std, var, mean) среднее арифметическое, 
# среднее квадратичное отклонение, смещенную и несмещенную оценки дисперсий для данной выборки.
import pandas as pd

salary_str = '100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150'
salary = list(map(int, salary_str.split(', ')))
salary.sort()
print(salary)
# средне арифметическое
mean = sum(salary)/len(salary)
print(f'среднее арифметическое {mean}')
# несмещенная оценка дисперсии
sumX = 0
for i in salary:
    X = pow(i - mean, 2)
    sumX += X
Dipersia_non = sumX/(len(salary)-1)
print(f'несмещенная оценка дисперсии {Dipersia_non}')
# смещенная оценка дисперсии
Dipersia = sumX/(len(salary))
print(f'смещенная оценка дисперсии {Dipersia}')
# среднее квадратичное отклонение
STD = pow(Dipersia_non, 0.5)
print(f'среднее квадратичное отклонение {STD}')

df = pd.DataFrame(salary)
print()
# print(df)
mean = df.mean()
print(mean)
Dipersia = df.var(ddof=0)
print(Dipersia)
# Out:
# [17, 24, 25, 30, 33, 45, 55, 57, 65, 65, 70, 75, 75, 77, 80, 84, 89, 90, 100, 150]
# среднее арифметическое 65.3
# несмещенная оценка дисперсии 1000.1157894736842
# смещенная оценка дисперсии 950.11
# среднее квадратичное отклонение 31.624607341019814
#
#     0
# 0  65
# 1  75
# 0    950.11
# dtype: float64

# %%
# В первом ящике находится 8 мячей, из которых 5 - белые. Во втором ящике - 12 мячей, из которых 5 белых. Из первого ящика 
# вытаскивают случайным образом два мяча, из второго - 4. Какова вероятность того, что 3 мяча белые?

from IPython.display import display
from numpy import math

def composite(n, k):
    N = math.factorial(n)/(math.factorial(k)*math.factorial(n-k))
    return N
# Для решения рассмотрим необходимо вычислить полную вероятность комбинации независимых событий. А именно:
#     здесь возможна комбинация 1 ящик - 0 белых шаров, 2 ящик 3 белых шара; 1 ящик - 1 белый шар, 2 ящик - 2 белых шара;
#     1 ящик - 2 белых шаров, 2 ящик - 1 белый шар
# Вычислим количество искомых исходов для 1-го и 2-го ящика
print('Вычислим количество искомых исходов для 1-го и 2-го ящика\n box1M1w = composite(5, 0)\n box1M1b = composite(3, 2)...')
box1M1w = composite(5, 0)
box1M1b = composite(3, 2)
box1M2w = composite(5, 1)
box1M2b = composite(3, 1)
box1M3w = composite(5, 2)
box1M3b = composite(3, 0)
box1N = composite(8, 2)

box2M1w = composite(5, 3)
box2M1b = composite(7, 1)
box2M2w = composite(5, 2)
box2M2b = composite(7, 2)
box2M3w = composite(5, 1)
box2M3b = composite(7, 3)
box2N = composite(12, 4)

# Тогда полная вероятность: 
print('Тогда полная вероятность: Pcom = (box1M1w*box1M1b/box1N)*(box2M1w*box2M1b/box2N) + (box1M2w*box1M2b/box1N)*(box2M2w*box2M2b/box2N) \
+ (box1M3w*box1M3b/box1N)*(box2M3w*box2M3b/box2N)')
Pcom = (box1M1w*box1M1b/box1N)*(box2M1w*box2M1b/box2N) + (box1M2w*box1M2b/box1N)*(box2M2w*box2M2b/box2N) \
+ (box1M3w*box1M3b/box1N)*(box2M3w*box2M3b/box2N)
print(f'Вероятность того что все 3 мяча  из 6 белые {Pcom}\n')

# Альтернативный способ:
# Поскольку событие достать шар равновероятно для любой корзины сдлеаем допущение и рассмотрим как будто шары лежат в одной корзине
# Тогда условие можно переформулировать след образом в корзине лежит 20 шаров из ни 10 белых 10 черных. Тогда найдем вероятность того 
# что 3 шара из 6 белые:
print('Альтернативный способ:')
print('Поскольку событие достать шар равновероятно для любой корзины сделеаем допущение и рассмотрим как будто шары лежат \
в одной корзине Тогда условие можно переформулировать след образом в корзине лежит 20 шаров из ни 10 белых 10 черных. \
Тогда найдем вероятность того что 3 шара из 6 белые')

Ncom = composite(20, 6)
Mwcom = composite(10, 3)
Mbcom = composite(10, 3)
Pw = (Mwcom * Mbcom) / Ncom
print(f'Вероятность того что все 3 мяча из 6 белые  Pw = N/M = {Pw}\n')
# Out:
# Вычислим количество искомых исходов для 1-го и 2-го ящика
#  box1M1w = composite(5, 0)
#  box1M1b = composite(3, 2)...
# Тогда полная вероятность: Pcom = (box1M1w*box1M1b/box1N)*(box2M1w*box2M1b/box2N) + (box1M2w*box1M2b/box1N)*(box2M2w*box2M2b/box2N) + (box1M3w*box1M3b/box1N)*(box2M3w*box2M3b/box2N)
# Вероятность того что все 3 мяча  из 6 белые 0.3686868686868687
#
# Альтернативный способ:
# Поскольку событие достать шар равновероятно для любой корзины сделеаем допущение и рассмотрим как будто шары лежат в одной корзине Тогда условие можно переформулировать след образом в корзине лежит 20 шаров из ни 10 белых 10 черных. Тогда найдем вероятность того что 3 шара из 6 белые
# Вероятность того что все 3 мяча из 6 белые  Pw = N/M = 0.3715170278637771

# %%
# На соревновании по биатлону один из трех спортсменов стреляет и попадает в мишень. Вероятность попадания для первого спортсмена 
# равна 0.9, для второго — 0.8, для третьего — 0.6. Найти вероятность того, что выстрел произведен: a). первым спортсменом 
# б). вторым спортсменом в). третьим спортсменом.

print('Запишем формулу Байеса для произошедшего события: P(B|A) = P(A|B)*P(B)/P(A), где P(A|B) вероятность попадания того или \
иного стрелка если стрелял он(событие В), где P(A|B) вероятность попадания биатлонистом, при условии что стрелял он. \
P(B)- вероятность того что стрелял биатлонист равна 1/3 событие равновероятно. P(A) - полная вероятность. ')
print('Вычислим полную вероятность P(A) = P(𝐵_1)∗𝑃(𝐴│𝐵_1 )+𝑃(𝐵_2 )∗𝑃(𝐴│𝐵_2 )+𝑃(𝐵_3 )∗𝑃(𝐴│𝐵_3 )')
Pa = (1/3)*0.9+(1/3)*0.8+(1/3)*0.6
print(f'Pa = {Pa}')
print('Вычислим вероятность что это был первый биатлонист P(B|A)1')
P1 = 0.9*(1/3)/Pa
print(f'P1 = {P1}')
P2 = 0.8*(1/3)/Pa
print(f'P2 = {P2}')
P3 = 0.6*(1/3)/Pa
print(f'P3 = {P3}')
print('\nАльтернативный способ:')
print('Поскольку выбор биатлонистов равновероятен нормируем вероятностm попадания отдельного биатлониста к сумме\
вероятностей попадания каждого биатлониста:')
print('Pn = P(𝐵n)/P(𝐵1)+𝑃(𝐵2)+𝑃(𝐵3)')
P1 = 0.9/(0.9+0.8+0.6)
print(f'P1 = {P1}')
P2 = 0.8/(0.9+0.8+0.6)
print(f'P2 = {P2}')
P2 = 0.6/(0.9+0.8+0.6)
print(f'P3 = {P3}')
# Out:
# Запишем формулу Байеса для произошедшего события: P(B|A) = P(A|B)*P(B)/P(A), где P(A|B) вероятность попадания того или иного стрелка если стрелял он(событие В), где P(A|B) вероятность попадания биатлонистом, при условии что стрелял он. P(B)- вероятность того что стрелял биатлонист равна 1/3 событие равновероятно. P(A) - полная вероятность.
# Вычислим полную вероятность P(A) = P(𝐵_1)∗𝑃(𝐴│𝐵_1 )+𝑃(𝐵_2 )∗𝑃(𝐴│𝐵_2 )+𝑃(𝐵_3 )∗𝑃(𝐴│𝐵_3 )
# Pa = 0.7666666666666666
# Вычислим вероятность что это был первый игрок P(B|A)1
# P1 = 0.391304347826087
# P2 = 0.3478260869565218
# P3 = 0.2608695652173913
#
# Альтернативный способ:
# Поскольку выбор биатлонистов равновероятен нормируем вероятностm попадания отдельного биатлониста к суммевероятностей попадания каждого биатлониста:
# Pn = P(𝐵n)/P(𝐵1)+𝑃(𝐵2)+𝑃(𝐵3)
# P1 = 0.3913043478260869
# P2 = 0.34782608695652173
# P3 = 0.2608695652173913

# %%
# В университет на факультеты A и B поступило равное количество студентов, а на факультет C студентов поступило столько же, 
# сколько на A и B вместе. Вероятность того, что студент факультета A сдаст первую сессию, равна 0.8. Для студента факультета 
# B эта вероятность равна 0.7, а для студента факультета C - 0.9. Студент сдал первую сессию. Какова вероятность, что он учится: 
# a). на факультете A б). на факультете B в). на факультете C?

print('Обозначим количество  студентов на факультете A = x, тогда B = x, C = 2x')
print('Априорные вероятности P(B)a = x/4x = 1/4, P(B)b = x/4x =1/4, P(B)c = 2x/4x = 1/2 ')
print('Запишем формулу Байеса для произошедшего события: P(B|A) = P(A|B)*P(B)/P(A)')
print('Вычислим полную вероятность P(A) = P(𝐵_1)∗𝑃(𝐴│𝐵_1 )+𝑃(𝐵_2 )∗𝑃(𝐴│𝐵_2 )+𝑃(𝐵_3 )∗𝑃(𝐴│𝐵_3 )')
Pa = (1/4)*(0.8+0.7+2*0.9)
print(f'Pa = {Pa}')
print('Вычислим вероятности для факультета А, B, C')
PfakA = 0.8*(1/4)/Pa
print(f'P(B|A)a = {PfakA}')
PfakB = 0.7*(1/4)/Pa
print(f'P(B|A)b = {PfakB}')
PfakC = 0.9*(1/2)/Pa
print(f'P(B|A)c = {PfakC}')
# Out:
# Обозначим количество  студентов на факультете A = x, тогда B = x, C = 2x
# Априорные вероятности P(B)a = x/4x = 1/4, P(B)b = x/4x =1/4, P(B)c = 2x/4x = 1/2
# Запишем формулу Байеса для произошедшего события: P(B|A) = P(A|B)*P(B)/P(A)
# Вычислим полную вероятность P(A) = P(𝐵_1)∗𝑃(𝐴│𝐵_1 )+𝑃(𝐵_2 )∗𝑃(𝐴│𝐵_2 )+𝑃(𝐵_3 )∗𝑃(𝐴│𝐵_3 )
# Pa = 0.825
# Вычислим вероятности для факультета А, B, C
# P(B|A)a = 0.24242424242424246
# P(B|A)b = 0.21212121212121213
# P(B|A)c = 0.5454545454545455

# %%
# Устройство состоит из трех деталей. Для первой детали вероятность выйти из строя в первый месяц равна 0.1, для второй - 0.2,
# для третьей - 0.25. Какова вероятность того, что в первый месяц выйдут из строя: а). все детали б). только две детали в). 
# хотя бы одна деталь г). от одной до двух деталей?
print('A)')
print('Посчитаем вероятность выхода из строя 3 деталей в первый месяц как вероятность 3-х независ событий P(123) = P1*P2*P3')
P123 = 0.1*0.2*0.25
print(f'Pа = {P123}')
print('Б)')
print('Посчитаем вероятность выхода из строя 2 деталей в первый месяц, как сумму вероятностей 3-х независымых событий\n \
1-сломалась 2- сломалаь 3 - не сломалась P3н = 1-P3. Pб = P1*P2*P3н+P1*P2н*P3+P1н*P2*P3')
Pb = 0.1*0.2*0.75 + 0.1*0.8*0.25 + 0.9*0.2*0.25
# Pb = 0.1*0.2 + 0.1*0.25 + 0.2*0.25
print(f'Pб = {Pb}')
print('В)')
print('Посчитаем вероятность выхода из строя хотя бы одной детали, Т.е. одной двух или трех. Последние 2 нам известны \
расчитаем вероятность выхода из строя 1 детали. ')
Pc1 = 0.2*0.9*0.75+0.1*0.8*0.75+0.25*0.9*0.8
Pc = P123 + Pb + Pc1
print(f'Pв = {Pc}')
print('Г)')
print('Посчитаем вероятность выхода из строя хотя бы одной или двух, как сумму выхода одной и двух деталей')
Pg = Pb + Pc1
print(f'Pг = {Pg}')
# p = P123 + Pb + Pc + Pg
# print(p)
# Out:
# A)
# Посчитаем вероятность выхода из строя 3 деталей в первый месяц как вероятность 3-х независ событий P(123) = P1*P2*P3
# Pа = 0.005000000000000001
# Б)
# Посчитаем вероятность выхода из строя 2 деталей в первый месяц, как сумму вероятностей 3-х независымых событий
#  1-сломалась 2- сломалаь 3 - не сломалась P3н = 1-P3. Pб = P1*P2*P3н+P1*P2н*P3+P1н*P2*P3
# Pб = 0.08000000000000002
# В)
# Посчитаем вероятность выхода из строя хотя бы одной детали, Т.е. одной двух или трех. Последние 2 нам известны расчитаем вероятность выхода из строя 1 детали.
# Pв = 0.46
# Г)
# Посчитаем вероятность выхода из строя хотя бы одной или двух, как сумму выхода одной и двух деталей
# Pг = 0.455
